# %%
import requests

# %%
url = "https://api.corona-zahlen.org/districts"

response = requests.get(url).json()

# %%
response["data"]
# Out:
# {'10041': {'ags': '10041',
#   'name': 'Regionalverband Saarbrücken',
#   'county': 'LK Stadtverband Saarbrücken',
#   'state': 'Saarland',
#   'population': 327284,
#   'cases': 155905,
#   'deaths': 1034,
#   'casesPerWeek': 5,
#   'deathsPerWeek': 0,
#   'stateAbbreviation': 'SL',
#   'recovered': 154852,
#   'weekIncidence': 1.527725156133511,
#   'casesPer100k': 47635.99809339901,
#   'delta': {'cases': 1,
#    'deaths': 0,
#    'recovered': 2,
#    'weekIncidence': -2.444360249766}},
#  '10042': {'ags': '10042',
#   'name': 'Merzig-Wadern',
#   'county': 'LK Merzig-Wadern',
#   'state': 'Saarland',
#   'population': 103426,
#   'cases': 55267,
#   'deaths': 235,
#   'casesPerWeek': 5,
#   'deathsPerWeek': 0,
#   'stateAbbreviation': 'SL',
#   'recovered': 55025,
#   'weekIncidence': 4.834374335273529,
#   'casesPer100k': 53436.273277512424,
#   'delta': {'cases': 1,
#    'deaths': 0,
#    'recovered': 1,
#    'weekIncidence': 0.966874867074}},
#  '10043': {'ags': '10043',
# ...
