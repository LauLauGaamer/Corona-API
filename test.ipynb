# %%
import requests

# %%
url = "https://api.corona-zahlen.org/germany/history/recovered"

response = requests.get(url)

# %%
response.json()
# Out:
# {'data': [{'recovered': 0, 'date': '2020-01-01T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-01-02T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-03T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-04T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-05T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-06T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-07T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-08T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-09T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-10T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-11T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-12T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-13T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-14T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-15T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-16T00:00:00.000Z'},
#   {'recovered': 0, 'date': '2020-01-17T00:00:00.000Z'},
# ...
